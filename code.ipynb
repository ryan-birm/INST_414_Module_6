# %% [markdown]
# # Detecting Speed Limit Signs with Dinov2: a Supervised-Learning Study

# %% [markdown]
# ### Imports

# %%
import torch
from ultralytics import YOLO
import os
import csv
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# %% [markdown]
# ### Train The Model

# %%
# Load pretrained YOLO11n classification model
model = YOLO("yolo11n-cls.pt")

# Train on Images folder
# The Images folder should contain subdirectories for each class:
# Images/
#   speed_limit/
#   no_speed_limit/
results = model.train(data="Images", epochs=20, imgsz=64)
# Out:
# Ultralytics 8.3.234 🚀 Python-3.13.0 torch-2.9.1 CPU (Apple M4)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=Images, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=20, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=64, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n-cls.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/runs/classify/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# WARNING ⚠️ Dataset 'split=train' not found at /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images/train
# Found 295 images in subdirectories. Attempting to split...
# Splitting /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images (2 classes, 296 images) into 80% train, 20% val...
# Split complete in /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split ✅
# train: /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/train... found 289 images in 2 classes ✅
# val: /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/val... found 136 images in 2 classes ✅
# ERROR ❌ test: /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test... found 85 images in 1 classes (requires 2 classes, not 1)
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  10                  -1  1    332802  ultralytics.nn.modules.head.Classify         [256, 2]
# YOLO11n-cls summary: 86 layers, 1,533,666 parameters, 1,533,666 gradients, 3.3 GFLOPs
# Transferred 234/236 items from pretrained weights
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 389.3±103.2 MB/s, size: 65.8 KB)
# train: Scanning /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/train... 289 images, 0 corrupt: 100% ━━━━━━━━━━━━ 289/289 1.6Kit/s 0.2s<0.2s
# train: New cache created: /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/train.cache
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 472.3±122.7 MB/s, size: 76.0 KB)
# val: Scanning /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/val... 136 images, 0 corrupt: 100% ━━━━━━━━━━━━ 136/136 1.3Kit/s 0.1s<0.1s
# val: New cache created: /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/val.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 39 weight(decay=0.0), 40 weight(decay=0.0005), 40 bias(decay=0.0)
# Image sizes 64 train, 64 val
# Using 0 dataloader workers
# Logging results to /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/runs/classify/train
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#        1/20         0G     0.6066          1         64: 100% ━━━━━━━━━━━━ 19/19 2.5it/s 7.7s0.8s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.8it/s 2.8s0.9s
#                    all      0.868          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        2/20         0G     0.4043          1         64: 100% ━━━━━━━━━━━━ 19/19 2.5it/s 7.5s0.8s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.8it/s 2.8s0.9s
#                    all      0.941          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        3/20         0G     0.2364          1         64: 100% ━━━━━━━━━━━━ 19/19 2.6it/s 7.3s0.7s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.8it/s 2.8s0.9ss
#                    all      0.956          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        4/20         0G     0.2182          1         64: 100% ━━━━━━━━━━━━ 19/19 2.6it/s 7.4s0.8s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.8it/s 2.8s0.9s
#                    all      0.985          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        5/20         0G     0.2007          1         64: 100% ━━━━━━━━━━━━ 19/19 2.6it/s 7.4s0.9s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.8it/s 2.8s0.8s
#                    all      0.993          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        6/20         0G     0.2728          1         64: 100% ━━━━━━━━━━━━ 19/19 2.6it/s 7.4s0.8s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.8it/s 2.8s0.9s
#                    all          1          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        7/20         0G     0.1282          1         64: 100% ━━━━━━━━━━━━ 19/19 2.6it/s 7.4s0.8s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.8it/s 2.8s0.8ss
#                    all          1          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        8/20         0G     0.3167          1         64: 100% ━━━━━━━━━━━━ 19/19 2.5it/s 7.5s0.8s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.8it/s 2.8s0.8s
#                    all          1          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        9/20         0G     0.3659          1         64: 100% ━━━━━━━━━━━━ 19/19 2.5it/s 7.7s0.9s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.8it/s 2.9s0.9ss
#                    all          1          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       10/20         0G     0.3519          1         64: 100% ━━━━━━━━━━━━ 19/19 2.6it/s 7.4s0.8s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.8it/s 2.8s0.8s
#                    all      0.985          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       11/20         0G     0.1429          1         64: 100% ━━━━━━━━━━━━ 19/19 2.6it/s 7.4s0.8s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.7it/s 3.0s0.9ss
#                    all      0.985          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       12/20         0G     0.1017          1         64: 100% ━━━━━━━━━━━━ 19/19 2.6it/s 7.4s0.8s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.6it/s 3.1s0.9s
#                    all          1          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       13/20         0G     0.3798          1         64: 100% ━━━━━━━━━━━━ 19/19 2.5it/s 7.6s0.8s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.8it/s 2.8s0.9s
#                    all          1          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       14/20         0G     0.1036          1         64: 100% ━━━━━━━━━━━━ 19/19 2.6it/s 7.3s0.8s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.8it/s 2.7s0.9s
#                    all          1          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       15/20         0G     0.3336          1         64: 100% ━━━━━━━━━━━━ 19/19 2.6it/s 7.3s0.8s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.8it/s 2.7s0.8s
#                    all          1          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       16/20         0G    0.06349          1         64: 100% ━━━━━━━━━━━━ 19/19 2.6it/s 7.3s0.8s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.8it/s 2.8s0.8s
#                    all          1          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       17/20         0G     0.2648          1         64: 100% ━━━━━━━━━━━━ 19/19 2.6it/s 7.3s0.8s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.8it/s 2.8s0.9s
#                    all          1          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       18/20         0G     0.3047          1         64: 100% ━━━━━━━━━━━━ 19/19 2.6it/s 7.3s0.8s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.8it/s 2.8s0.9s
#                    all          1          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       19/20         0G    0.06982          1         64: 100% ━━━━━━━━━━━━ 19/19 2.5it/s 7.5s0.9s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.9s
#                    all          1          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       20/20         0G    0.06938          1         64: 100% ━━━━━━━━━━━━ 19/19 2.5it/s 7.5s0.8s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.9s
#                    all          1          1
#
# 20 epochs completed in 0.057 hours.
# Optimizer stripped from /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/runs/classify/train/weights/last.pt, 3.2MB
# Optimizer stripped from /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/runs/classify/train/weights/best.pt, 3.2MB
#
# Validating /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/runs/classify/train/weights/best.pt...
# Ultralytics 8.3.234 🚀 Python-3.13.0 torch-2.9.1 CPU (Apple M4)
# YOLO11n-cls summary (fused): 47 layers, 1,528,586 parameters, 0 gradients, 3.2 GFLOPs
# WARNING ⚠️ Dataset 'split=train' not found at /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images/train
# Found 295 images in subdirectories. Attempting to split...
# Splitting /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images (2 classes, 296 images) into 80% train, 20% val...
# Split complete in /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split ✅
# train: /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/train... found 289 images in 2 classes ✅
# val: /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/val... found 136 images in 2 classes ✅
# ERROR ❌ test: /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test... found 85 images in 1 classes (requires 2 classes, not 1)
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.7it/s 2.9s0.8ss
#                    all          1          1
# Speed: 0.0ms preprocess, 2.5ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/runs/classify/train

# %% [markdown]
# ### Test The Model and Save Results

# %%
results = model("Images_split/test")
csv_filename = "test_predictions.csv"
with open(csv_filename, "w", newline="") as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["filename", "predicted_class", "confidence"])
    for r in results:
        fname = r.path.split("/")[-1]  # get only filename
        class_idx = r.probs.top1
        class_name = r.names[class_idx]
        confidence = r.probs.top1conf.item()
        writer.writerow([fname, class_name, confidence])
# Out:
# image 1/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00516.jpg: 64x64 no_speed_limit 1.00, speed_limit 0.00, 6.0ms
# image 2/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00517.jpg: 64x64 no_speed_limit 0.99, speed_limit 0.01, 1.8ms
# image 3/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00521.jpg: 64x64 no_speed_limit 1.00, speed_limit 0.00, 2.3ms
# image 4/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00522.jpg: 64x64 no_speed_limit 1.00, speed_limit 0.00, 2.1ms
# image 5/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00523.jpg: 64x64 no_speed_limit 1.00, speed_limit 0.00, 2.0ms
# image 6/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00524.jpg: 64x64 no_speed_limit 0.97, speed_limit 0.03, 1.5ms
# image 7/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00535.jpg: 64x64 no_speed_limit 0.99, speed_limit 0.01, 1.6ms
# image 8/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00536.jpg: 64x64 no_speed_limit 0.99, speed_limit 0.01, 1.6ms
# image 9/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00547.jpg: 64x64 no_speed_limit 1.00, speed_limit 0.00, 1.9ms
# image 10/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00548.jpg: 64x64 no_speed_limit 1.00, speed_limit 0.00, 1.6ms
# image 11/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00549.jpg: 64x64 no_speed_limit 1.00, speed_limit 0.00, 1.7ms
# image 12/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00554.jpg: 64x64 no_speed_limit 0.99, speed_limit 0.01, 1.7ms
# image 13/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00555.jpg: 64x64 no_speed_limit 1.00, speed_limit 0.00, 1.6ms
# image 14/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00558.jpg: 64x64 no_speed_limit 1.00, speed_limit 0.00, 2.0ms
# image 15/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00559.jpg: 64x64 speed_limit 0.50, no_speed_limit 0.50, 1.7ms
# image 16/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00560.jpg: 64x64 no_speed_limit 0.87, speed_limit 0.13, 1.5ms
# image 17/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00561.jpg: 64x64 no_speed_limit 1.00, speed_limit 0.00, 2.4ms
# image 18/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00562.jpg: 64x64 no_speed_limit 1.00, speed_limit 0.00, 2.5ms
# image 19/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00567.jpg: 64x64 no_speed_limit 0.99, speed_limit 0.01, 2.1ms
# image 20/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00568.jpg: 64x64 no_speed_limit 1.00, speed_limit 0.00, 2.4ms
# image 21/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00569.jpg: 64x64 no_speed_limit 1.00, speed_limit 0.00, 1.9ms
# image 22/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00570.jpg: 64x64 no_speed_limit 1.00, speed_limit 0.00, 2.1ms
# image 23/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00577.jpg: 64x64 no_speed_limit 1.00, speed_limit 0.00, 1.7ms
# image 24/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00585.jpg: 64x64 no_speed_limit 0.59, speed_limit 0.41, 1.5ms
# image 25/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00586.jpg: 64x64 no_speed_limit 1.00, speed_limit 0.00, 1.7ms
# image 26/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00590.jpg: 64x64 no_speed_limit 1.00, speed_limit 0.00, 1.8ms
# image 27/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00593.jpg: 64x64 no_speed_limit 1.00, speed_limit 0.00, 1.6ms
# image 28/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00594.jpg: 64x64 no_speed_limit 1.00, speed_limit 0.00, 1.6ms
# image 29/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00595.jpg: 64x64 no_speed_limit 1.00, speed_limit 0.00, 1.6ms
# image 30/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00596.jpg: 64x64 no_speed_limit 1.00, speed_limit 0.00, 1.5ms
# image 31/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00597.jpg: 64x64 no_speed_limit 1.00, speed_limit 0.00, 2.4ms
# image 32/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00598.jpg: 64x64 no_speed_limit 1.00, speed_limit 0.00, 1.9ms
# image 33/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00599.jpg: 64x64 no_speed_limit 1.00, speed_limit 0.00, 1.7ms
# image 34/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00605.jpg: 64x64 no_speed_limit 1.00, speed_limit 0.00, 1.6ms
# image 35/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00609.jpg: 64x64 no_speed_limit 1.00, speed_limit 0.00, 1.7ms
# image 36/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00611.jpg: 64x64 no_speed_limit 1.00, speed_limit 0.00, 1.8ms
# image 37/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00619.jpg: 64x64 no_speed_limit 0.78, speed_limit 0.22, 2.3ms
# image 38/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00621.jpg: 64x64 no_speed_limit 1.00, speed_limit 0.00, 1.6ms
# image 39/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00622.jpg: 64x64 no_speed_limit 1.00, speed_limit 0.00, 1.5ms
# image 40/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00623.jpg: 64x64 no_speed_limit 1.00, speed_limit 0.00, 1.6ms
# image 41/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00642.jpg: 64x64 speed_limit 0.92, no_speed_limit 0.08, 1.7ms
# image 42/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00643.jpg: 64x64 speed_limit 0.79, no_speed_limit 0.21, 1.5ms
# image 43/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00646.jpg: 64x64 no_speed_limit 1.00, speed_limit 0.00, 1.5ms
# image 44/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00648.jpg: 64x64 no_speed_limit 1.00, speed_limit 0.00, 2.0ms
# image 45/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00650.jpg: 64x64 no_speed_limit 1.00, speed_limit 0.00, 1.7ms
# image 46/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00651.jpg: 64x64 no_speed_limit 1.00, speed_limit 0.00, 1.7ms
# image 47/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00652.jpg: 64x64 no_speed_limit 1.00, speed_limit 0.00, 1.6ms
# image 48/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00656.jpg: 64x64 no_speed_limit 0.86, speed_limit 0.14, 1.6ms
# image 49/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00659.jpg: 64x64 no_speed_limit 0.98, speed_limit 0.02, 1.9ms
# image 50/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00661.jpg: 64x64 no_speed_limit 1.00, speed_limit 0.00, 1.7ms
# image 51/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00662.jpg: 64x64 no_speed_limit 1.00, speed_limit 0.00, 1.8ms
# image 52/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00671.jpg: 64x64 no_speed_limit 0.92, speed_limit 0.08, 1.7ms
# image 53/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00672.jpg: 64x64 no_speed_limit 1.00, speed_limit 0.00, 1.5ms
# image 54/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00675.jpg: 64x64 no_speed_limit 1.00, speed_limit 0.00, 1.7ms
# image 55/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00676.jpg: 64x64 no_speed_limit 1.00, speed_limit 0.00, 1.7ms
# image 56/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00677.jpg: 64x64 no_speed_limit 1.00, speed_limit 0.00, 1.4ms
# image 57/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00678.jpg: 64x64 no_speed_limit 1.00, speed_limit 0.00, 1.4ms
# image 58/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00682.jpg: 64x64 no_speed_limit 1.00, speed_limit 0.00, 1.5ms
# image 59/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00688.jpg: 64x64 no_speed_limit 1.00, speed_limit 0.00, 1.6ms
# image 60/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00691.jpg: 64x64 no_speed_limit 0.90, speed_limit 0.10, 1.5ms
# image 61/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00692.jpg: 64x64 no_speed_limit 1.00, speed_limit 0.00, 1.6ms
# image 62/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00694.jpg: 64x64 no_speed_limit 0.99, speed_limit 0.01, 1.7ms
# image 63/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00695.jpg: 64x64 no_speed_limit 1.00, speed_limit 0.00, 1.7ms
# image 64/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00696.jpg: 64x64 no_speed_limit 1.00, speed_limit 0.00, 1.5ms
# image 65/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00699.jpg: 64x64 no_speed_limit 1.00, speed_limit 0.00, 2.2ms
# image 66/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00700.jpg: 64x64 no_speed_limit 1.00, speed_limit 0.00, 1.9ms
# image 67/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00701.jpg: 64x64 no_speed_limit 1.00, speed_limit 0.00, 1.6ms
# image 68/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00702.jpg: 64x64 no_speed_limit 1.00, speed_limit 0.00, 1.5ms
# image 69/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00703.jpg: 64x64 no_speed_limit 1.00, speed_limit 0.00, 1.5ms
# image 70/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00704.jpg: 64x64 no_speed_limit 0.99, speed_limit 0.01, 1.6ms
# image 71/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00705.jpg: 64x64 speed_limit 0.67, no_speed_limit 0.33, 1.4ms
# image 72/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00706.jpg: 64x64 no_speed_limit 0.71, speed_limit 0.29, 1.6ms
# image 73/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/00707.jpg: 64x64 no_speed_limit 1.00, speed_limit 0.00, 1.6ms
# image 74/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/IMG_0486_jpg.rf.37fe7da32eab0456ccca1fa94564e15f.jpg: 64x64 speed_limit 1.00, no_speed_limit 0.00, 2.3ms
# image 75/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/IMG_0615_jpg.rf.76e4575c4460b1f1da4882d98f2a3470.jpg: 64x64 speed_limit 1.00, no_speed_limit 0.00, 2.3ms
# image 76/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/IMG_0653_jpg.rf.46b2e278a174bae12aa5586c8184cb74.jpg: 64x64 speed_limit 1.00, no_speed_limit 0.00, 1.5ms
# image 77/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/SAM_0205_JPG.rf.84ef06970922cec70b0eac7dd5760670.jpg: 64x64 speed_limit 1.00, no_speed_limit 0.00, 2.0ms
# image 78/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/SAM_0888_JPG.rf.89c179139a8630e4abb5c9a18e24c0ea.jpg: 64x64 speed_limit 1.00, no_speed_limit 0.00, 1.8ms
# image 79/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/SAM_1212_JPG.rf.6593d2c803d33f0cb39fe0a2799d284d.jpg: 64x64 speed_limit 1.00, no_speed_limit 0.00, 1.7ms
# image 80/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/SAM_1213_JPG.rf.6d7367111afe2c12c6f33caa8c278c92.jpg: 64x64 speed_limit 1.00, no_speed_limit 0.00, 1.9ms
# image 81/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/n50_jpg.rf.e1ff81f75b69723118f7fd2afbcae2c6.jpg: 64x64 speed_limit 0.96, no_speed_limit 0.04, 1.4ms
# image 82/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/n67_jpg.rf.47bdab2ace748ba351a5401bb7df0d11.jpg: 64x64 speed_limit 1.00, no_speed_limit 0.00, 1.4ms
# image 83/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/n68_jpg.rf.f11f69d038e06648565d9c72707eff8c.jpg: 64x64 speed_limit 1.00, no_speed_limit 0.00, 1.4ms
# image 84/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/n9_JPG.rf.cf84af532d4f25f0452da54d21ae48d0.jpg: 64x64 speed_limit 1.00, no_speed_limit 0.00, 2.0ms
# image 85/85 /Users/ryanbirmingham/School Work/Fall2025/INST414/INST_414_Module_6/Images_split/test/test_image.jpeg: 64x64 speed_limit 0.95, no_speed_limit 0.05, 1.5ms
# Speed: 3.9ms preprocess, 1.8ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)

# %%
speed_limit_truth = os.listdir("Images_split/test_truth/speed_limit")
no_speed_limit_truth = os.listdir("Images_split/test_truth/no_speed_limit")

df = pd.read_csv("test_predictions.csv")
df["truth"] = df["filename"].apply(lambda x: "speed_limit" if x in speed_limit_truth else "no_speed_limit")
df["correct"] = df["predicted_class"] == df["truth"]

print(df["correct"].value_counts())
print(df["correct"].value_counts(normalize=True))
print("--------------------------------")
print("These are the correct predictions:")
correct = df[df["correct"] == True]
print(correct[["filename", "predicted_class", "truth"]][:5])
print("--------------------------------")
print("These are the incorrect predictions:")
incorrect = df[df["correct"] == False]
print(incorrect[["filename", "predicted_class", "truth"]][:5])

print("Unique in truth:", df["truth"].unique())
print("Unique in predicted:", df["predicted_class"].unique())


labels = ["no_speed_limit", "speed_limit"]
cm = confusion_matrix(df["truth"], df["predicted_class"], labels=labels)
df["truth"] = df["truth"].str.strip()
df["predicted_class"] = df["predicted_class"].str.strip()
plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.tight_layout()
plt.show()
# Out:
# correct
# True     76
# False     9
# Name: count, dtype: int64
# correct
# True     0.894118
# False    0.105882
# Name: proportion, dtype: float64
# --------------------------------
# These are the correct predictions:
#     filename predicted_class           truth
# 0  00516.jpg  no_speed_limit  no_speed_limit
# 1  00517.jpg  no_speed_limit  no_speed_limit
# 2  00521.jpg  no_speed_limit  no_speed_limit
# 3  00522.jpg  no_speed_limit  no_speed_limit
# 4  00523.jpg  no_speed_limit  no_speed_limit
# --------------------------------
# These are the incorrect predictions:
#      filename predicted_class           truth
# 14  00559.jpg     speed_limit  no_speed_limit
# 38  00622.jpg  no_speed_limit     speed_limit
# 40  00642.jpg     speed_limit  no_speed_limit
# 41  00643.jpg     speed_limit  no_speed_limit
# 54  00676.jpg  no_speed_limit     speed_limit
# Unique in truth: ['no_speed_limit' 'speed_limit']
# Unique in predicted: ['no_speed_limit' 'speed_limit']
